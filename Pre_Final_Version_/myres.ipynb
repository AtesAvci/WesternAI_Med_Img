# %%
import os
from os.path import join
from IPython.display import Image, display
import numpy as np
import tempfile
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model,Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation,MaxPooling2D,Dropout,BatchNormalization,AveragePooling2D,Input,ZeroPadding2D,Add

# %%
#data prep
train_path = 'C:\\Users\\Danial\\Documents\\chest_xray\\train'
val_path = 'C:\\Users\\Danial\\Documents\\chest_xray\\val'
test_path = 'C:\\Users\\Danial\\Documents\\chest_xray\\test'
train_batch = ImageDataGenerator(rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        validation_split=0.2,
        ).flow_from_directory(train_path,target_size = (100,100),classes =['NORMAL','PNEUMONIA'] ,batch_size=34,color_mode="rgb",subset="training")
test_batch = ImageDataGenerator(rescale=1/255).flow_from_directory(test_path,target_size = (100,100),classes =['NORMAL','PNEUMONIA'] ,color_mode="rgb")
val_batch = ImageDataGenerator(rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
        ,validation_split=0.2).flow_from_directory(train_path,target_size = (100,100),classes =['NORMAL','PNEUMONIA'],batch_size=4,color_mode="rgb",subset="validation")
# Out:
# Found 4199 images belonging to 2 classes.
# Found 644 images belonging to 2 classes.
# Found 1049 images belonging to 2 classes.

# %%
#Model structure Definitions
def convblock(X, f, filters):
    #Filter
    F1,F2,F3 = filters
    # Save the input value
    X_shortcut = X


    #MAIN PATH
    # First 
    X = Conv2D(F1, (1, 1), strides = (2,2))(X)
    X = Dropout(0.2)(X)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)

    # Second 
    X = X = Conv2D(F2, (f, f), strides = (1,1),padding = 'same',kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dropout(0.2)(X)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)

    # Third 
    X = X = Conv2D(F3, (1, 1), strides = (1,1),padding='valid',kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dropout(0.2)(X)
    X = BatchNormalization(axis=3)(X)

    
    #SHORTCUT PATH
    X_shortcut = Conv2D(F3, (1, 1), strides = (2,2),kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X = Dropout(0.2)(X)
    X_shortcut = BatchNormalization(axis = 3)(X_shortcut)

    # add shortcut
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
def idblock(X, f, filters):
    #filters
    F1,F2,F3=filters
    X_shortcut = X

    # First part
    X = Conv2D(F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid',kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)

    # Second part
    X = Conv2D(F2, kernel_size = (f, f), strides = (1,1), padding = 'same',kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dropout(0.2)(X)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)

    # Third part
    X = Conv2D(F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid',kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dropout(0.2)(X)
    X = BatchNormalization(axis = 3)(X)

    # Shortcut
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def myres(shape,classes):
    #Inputs
    X_input = Input(shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2))(X)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convblock(X, f = 3, filters = [16, 16, 64])
    X = idblock(X, 3, [16, 16, 64])
    X = idblock(X, 3, [16, 16, 64])

    # Stage 3
    X = convblock(X, f = 3, filters = [32, 32, 128])
    X = idblock(X, 3, [32, 32, 128])
    X = idblock(X, 3, [32, 32, 128])
    X = idblock(X, 3, [32, 32, 128])

    # Stage 4
    X = convblock(X, f = 3, filters = [64, 64, 256])
    X = idblock(X, 3, [64, 64, 256])
    X = idblock(X, 3, [64, 64, 256])
    X = idblock(X, 3, [64, 64, 256])
    X = idblock(X, 3, [64, 64, 256])
    X = idblock(X, 3, [64, 64, 256])

    # Stage 5
    X = convblock(X, f = 3, filters = [128, 128, 512])
    X = idblock(X, 3, [128, 128, 512])
    X = idblock(X, 3, [128, 128, 512])

    # AVGPOOL.
    X = AveragePooling2D((2, 2))(X)

    # output layer
    X = Flatten()(X)
    X = Dense(512,activation='relu')(X)
    X = Dropout(0.5)(X)
    X = Dense(classes, activation='softmax')(X)
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='myres')

    return model

# %%
my_net = myres(train_batch.image_shape,2)
my_net.summary()
my_net.compile(loss = 'categorical_crossentropy', optimizer = 'adam',metrics=['accuracy'])
# Out:
# Model: "myres"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 106, 106, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 50, 50, 64)   9472        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 50, 50, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 50, 50, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 24, 24, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 12, 12, 16)   1040        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 12, 12, 16)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 12, 12, 16)   64          dropout[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 12, 12, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 12, 12, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 12, 12, 16)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 12, 12, 16)   64          dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 12, 12, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 12, 64)   1088        activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 12, 12, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 12, 12, 64)   256         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 12, 12, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 12, 12, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 12, 12, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 12, 12, 64)   0           dropout_3[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 12, 12, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 12, 12, 16)   1040        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 12, 12, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 12, 12, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 12, 12, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 12, 12, 16)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 12, 12, 16)   64          dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 12, 12, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 12, 12, 64)   1088        activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 12, 12, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 12, 12, 64)   256         dropout_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 12, 12, 64)   0           batch_normalization_7[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 12, 12, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 12, 12, 16)   1040        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 12, 12, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 12, 12, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 12, 16)   2320        activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 12, 12, 16)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 12, 12, 16)   64          dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 12, 12, 16)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 12, 64)   1088        activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 12, 12, 64)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 12, 12, 64)   256         dropout_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 12, 12, 64)   0           batch_normalization_10[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 12, 12, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 6, 6, 32)     2080        activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 6, 6, 32)     0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 6, 6, 32)     128         dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 6, 6, 32)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 6, 6, 32)     9248        activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 6, 6, 32)     0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 6, 6, 32)     128         dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 6, 6, 32)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 6, 6, 128)    4224        activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 6, 6, 128)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 6, 6, 128)    512         dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 6, 6, 128)    8320        activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 6, 6, 128)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 6, 6, 128)    512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 6, 6, 128)    0           dropout_11[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 6, 6, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 6, 6, 32)     4128        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 6, 6, 32)     128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 6, 6, 32)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 6, 6, 32)     9248        activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 6, 6, 32)     0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 6, 6, 32)     128         dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 6, 6, 32)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 6, 6, 128)    4224        activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 6, 6, 128)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 6, 6, 128)    512         dropout_13[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 6, 6, 128)    0           batch_normalization_17[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 6, 6, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 6, 6, 32)     4128        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 6, 6, 32)     128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 6, 6, 32)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 6, 6, 32)     9248        activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 6, 6, 32)     0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 6, 6, 32)     128         dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 6, 6, 32)     0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 6, 6, 128)    4224        activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 6, 6, 128)    0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 6, 6, 128)    512         dropout_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 6, 6, 128)    0           batch_normalization_20[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 6, 6, 128)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 6, 6, 32)     4128        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 6, 6, 32)     128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 6, 6, 32)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 6, 6, 32)     9248        activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 6, 6, 32)     0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 6, 6, 32)     128         dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 6, 6, 32)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 6, 6, 128)    4224        activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 6, 6, 128)    0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 6, 6, 128)    512         dropout_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 6, 6, 128)    0           batch_normalization_23[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 128)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 3, 3, 64)     8256        activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 3, 3, 64)     0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 3, 3, 64)     256         dropout_18[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 3, 3, 64)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 3, 3, 64)     36928       activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 3, 3, 64)     0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 3, 3, 64)     256         dropout_19[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 3, 3, 64)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 3, 3, 256)    16640       activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 3, 3, 256)    0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 3, 3, 256)    1024        dropout_20[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 3, 3, 256)    33024       activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 3, 3, 256)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 3, 3, 256)    1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 3, 3, 256)    0           dropout_21[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 3, 3, 256)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 3, 3, 64)     16448       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 3, 3, 64)     256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 3, 3, 64)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 3, 3, 64)     36928       activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 3, 3, 64)     0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 3, 3, 64)     256         dropout_22[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 3, 3, 64)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 3, 3, 256)    16640       activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 3, 3, 256)    0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 3, 3, 256)    1024        dropout_23[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 3, 3, 256)    0           batch_normalization_30[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 3, 3, 256)    0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 3, 3, 64)     16448       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 3, 3, 64)     256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 3, 3, 64)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 3, 3, 64)     36928       activation_28[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 3, 3, 64)     0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 3, 3, 64)     256         dropout_24[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 3, 3, 64)     0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 3, 3, 256)    16640       activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 3, 3, 256)    0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 3, 3, 256)    1024        dropout_25[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 3, 3, 256)    0           batch_normalization_33[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 3, 3, 256)    0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 3, 3, 64)     16448       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 3, 3, 64)     256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 3, 3, 64)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 3, 3, 64)     36928       activation_31[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 3, 3, 64)     0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 3, 3, 64)     256         dropout_26[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 3, 3, 64)     0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 3, 3, 256)    16640       activation_32[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 3, 3, 256)    0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 3, 3, 256)    1024        dropout_27[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 3, 3, 256)    0           batch_normalization_36[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 3, 3, 256)    0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 3, 3, 64)     16448       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 3, 3, 64)     256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 3, 3, 64)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 3, 3, 64)     36928       activation_34[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 3, 3, 64)     0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 3, 3, 64)     256         dropout_28[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 3, 3, 64)     0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 3, 3, 256)    16640       activation_35[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 3, 3, 256)    0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 3, 3, 256)    1024        dropout_29[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 3, 3, 256)    0           batch_normalization_39[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 3, 3, 256)    0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 3, 3, 64)     16448       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 3, 3, 64)     256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 3, 3, 64)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 3, 3, 64)     36928       activation_37[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 3, 3, 64)     0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 3, 3, 64)     256         dropout_30[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 3, 3, 64)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 3, 3, 256)    16640       activation_38[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 3, 3, 256)    0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 3, 3, 256)    1024        dropout_31[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 3, 3, 256)    0           batch_normalization_42[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 3, 3, 256)    0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 2, 2, 128)    32896       activation_39[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 2, 2, 128)    0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 2, 2, 128)    512         dropout_32[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 2, 2, 128)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 2, 2, 128)    147584      activation_40[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 2, 2, 128)    0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 2, 2, 128)    512         dropout_33[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 2, 2, 128)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 2, 2, 512)    66048       activation_41[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 2, 2, 512)    0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 2, 2, 512)    2048        dropout_34[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 2, 2, 512)    131584      activation_39[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 2, 2, 512)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 2, 2, 512)    2048        conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 2, 2, 512)    0           dropout_35[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 2, 2, 512)    0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 2, 2, 128)    65664       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 2, 2, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 2, 2, 128)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 2, 2, 128)    147584      activation_43[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 2, 2, 128)    0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 2, 2, 128)    512         dropout_36[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 2, 2, 128)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 2, 2, 512)    66048       activation_44[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 2, 2, 512)    0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 2, 2, 512)    2048        dropout_37[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 2, 2, 512)    0           batch_normalization_49[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 2, 2, 512)    0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 2, 2, 128)    65664       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 2, 2, 128)    512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 2, 2, 128)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 2, 2, 128)    147584      activation_46[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 2, 2, 128)    0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 2, 2, 128)    512         dropout_38[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 2, 2, 128)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 2, 2, 512)    66048       activation_47[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 2, 2, 512)    0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 2, 2, 512)    2048        dropout_39[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 2, 2, 512)    0           batch_normalization_52[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 2, 2, 512)    0           add_15[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 512)    0           activation_48[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          262656      flatten[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            1026        dropout_40[0][0]
# ==================================================================================================
# Total params: 1,775,714
# Trainable params: 1,762,338
# Non-trainable params: 13,376
# __________________________________________________________________________________________________

# %%
checkpoint = ModelCheckpoint("./val", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
my_net.fit(train_batch,epochs = 50,callbacks=callbacks_list,validation_data = val_batch)
# Out:
# Epoch 1/50
# 124/124 [==============================] - ETA: 0s - loss: 0.7107 - accuracy: 0.7097
# Epoch 00001: val_accuracy improved from -inf to 0.74166, saving model to ./val
# WARNING:tensorflow:From c:\python\python38\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./val\assets
# 124/124 [==============================] - 152s 1s/step - loss: 0.7107 - accuracy: 0.7097 - val_loss: 0.7731 - val_accuracy: 0.7417
# Epoch 2/50
# 124/124 [==============================] - ETA: 0s - loss: 0.4305 - accuracy: 0.7833
# Epoch 00002: val_accuracy did not improve from 0.74166
# 124/124 [==============================] - 98s 794ms/step - loss: 0.4305 - accuracy: 0.7833 - val_loss: 1.5909 - val_accuracy: 0.7417
# Epoch 3/50
# 124/124 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.8557
# Epoch 00003: val_accuracy did not improve from 0.74166
# 124/124 [==============================] - 99s 801ms/step - loss: 0.3294 - accuracy: 0.8557 - val_loss: 1.7608 - val_accuracy: 0.7417
# Epoch 4/50
# 124/124 [==============================] - ETA: 0s - loss: 0.2930 - accuracy: 0.8750
# Epoch 00004: val_accuracy did not improve from 0.74166
# 124/124 [==============================] - 99s 798ms/step - loss: 0.2930 - accuracy: 0.8750 - val_loss: 1.9190 - val_accuracy: 0.7417
# Epoch 5/50
# 124/124 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.8883
# Epoch 00005: val_accuracy did not improve from 0.74166
# 124/124 [==============================] - 99s 798ms/step - loss: 0.2738 - accuracy: 0.8883 - val_loss: 0.6915 - val_accuracy: 0.6530
# Epoch 6/50
# 124/124 [==============================] - ETA: 0s - loss: 0.2431 - accuracy: 0.8995
# Epoch 00006: val_accuracy improved from 0.74166 to 0.89895, saving model to ./val
# INFO:tensorflow:Assets written to: ./val\assets
# 124/124 [==============================] - 148s 1s/step - loss: 0.2431 - accuracy: 0.8995 - val_loss: 0.2299 - val_accuracy: 0.8990
# Epoch 7/50
# 124/124 [==============================] - ETA: 0s - loss: 0.2473 - accuracy: 0.9035
# Epoch 00007: val_accuracy did not improve from 0.89895
# 124/124 [==============================] - 97s 780ms/step - loss: 0.2473 - accuracy: 0.9035 - val_loss: 0.3363 - val_accuracy: 0.8589
# Epoch 8/50
# 124/124 [==============================] - ETA: 0s - loss: 0.2467 - accuracy: 0.9074
# Epoch 00008: val_accuracy did not improve from 0.89895
# 124/124 [==============================] - 95s 763ms/step - loss: 0.2467 - accuracy: 0.9074 - val_loss: 0.2652 - val_accuracy: 0.8904
# Epoch 9/50
# 124/124 [==============================] - ETA: 0s - loss: 0.2243 - accuracy: 0.9057
# Epoch 00009: val_accuracy did not improve from 0.89895
# 124/124 [==============================] - 91s 733ms/step - loss: 0.2243 - accuracy: 0.9057 - val_loss: 0.2648 - val_accuracy: 0.8875
# Epoch 10/50
# 124/124 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9188
# Epoch 00010: val_accuracy did not improve from 0.89895
# 124/124 [==============================] - 90s 728ms/step - loss: 0.2165 - accuracy: 0.9188 - val_loss: 0.3178 - val_accuracy: 0.8847
# Epoch 11/50
# 124/124 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.9219
# Epoch 00011: val_accuracy did not improve from 0.89895
# 124/124 [==============================] - 91s 735ms/step - loss: 0.2065 - accuracy: 0.9219 - val_loss: 0.2634 - val_accuracy: 0.8904
# Epoch 12/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9252
# Epoch 00012: val_accuracy did not improve from 0.89895
# 124/124 [==============================] - 91s 735ms/step - loss: 0.1992 - accuracy: 0.9252 - val_loss: 0.6565 - val_accuracy: 0.7274
# Epoch 13/50
# 124/124 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9224
# Epoch 00013: val_accuracy did not improve from 0.89895
# 124/124 [==============================] - 91s 737ms/step - loss: 0.2125 - accuracy: 0.9224 - val_loss: 1.2404 - val_accuracy: 0.5806
# Epoch 14/50
# 124/124 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9250
# Epoch 00014: val_accuracy did not improve from 0.89895
# 124/124 [==============================] - 91s 738ms/step - loss: 0.2022 - accuracy: 0.9250 - val_loss: 0.3059 - val_accuracy: 0.8446
# Epoch 15/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1868 - accuracy: 0.9328
# Epoch 00015: val_accuracy did not improve from 0.89895
# 124/124 [==============================] - 86s 691ms/step - loss: 0.1868 - accuracy: 0.9328 - val_loss: 3.2501 - val_accuracy: 0.7417
# Epoch 16/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9324
# Epoch 00016: val_accuracy improved from 0.89895 to 0.89990, saving model to ./val
# INFO:tensorflow:Assets written to: ./val\assets
# 124/124 [==============================] - 129s 1s/step - loss: 0.1883 - accuracy: 0.9324 - val_loss: 0.2668 - val_accuracy: 0.8999
# Epoch 17/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1850 - accuracy: 0.9331
# Epoch 00017: val_accuracy did not improve from 0.89990
# 124/124 [==============================] - 83s 670ms/step - loss: 0.1850 - accuracy: 0.9331 - val_loss: 1.1894 - val_accuracy: 0.7741
# Epoch 18/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1932 - accuracy: 0.9314
# Epoch 00018: val_accuracy did not improve from 0.89990
# 124/124 [==============================] - 83s 670ms/step - loss: 0.1932 - accuracy: 0.9314 - val_loss: 0.4746 - val_accuracy: 0.7741
# Epoch 19/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1911 - accuracy: 0.9319
# Epoch 00019: val_accuracy improved from 0.89990 to 0.91039, saving model to ./val
# INFO:tensorflow:Assets written to: ./val\assets
# 124/124 [==============================] - 128s 1s/step - loss: 0.1911 - accuracy: 0.9319 - val_loss: 0.2075 - val_accuracy: 0.9104
# Epoch 20/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1790 - accuracy: 0.9350
# Epoch 00020: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 83s 673ms/step - loss: 0.1790 - accuracy: 0.9350 - val_loss: 0.4277 - val_accuracy: 0.8255
# Epoch 21/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1702 - accuracy: 0.9302
# Epoch 00021: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 83s 671ms/step - loss: 0.1702 - accuracy: 0.9302 - val_loss: 2.3931 - val_accuracy: 0.7417
# Epoch 22/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1818 - accuracy: 0.9336
# Epoch 00022: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 82s 662ms/step - loss: 0.1818 - accuracy: 0.9336 - val_loss: 1.6873 - val_accuracy: 0.4709
# Epoch 23/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1586 - accuracy: 0.9426
# Epoch 00023: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 83s 666ms/step - loss: 0.1586 - accuracy: 0.9426 - val_loss: 0.3129 - val_accuracy: 0.8866
# Epoch 24/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1599 - accuracy: 0.9386
# Epoch 00024: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 82s 663ms/step - loss: 0.1599 - accuracy: 0.9386 - val_loss: 4.2655 - val_accuracy: 0.3966
# Epoch 25/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9400
# Epoch 00025: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 82s 662ms/step - loss: 0.1686 - accuracy: 0.9400 - val_loss: 0.2287 - val_accuracy: 0.8990
# Epoch 26/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1654 - accuracy: 0.9447
# Epoch 00026: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 82s 662ms/step - loss: 0.1654 - accuracy: 0.9447 - val_loss: 0.3047 - val_accuracy: 0.8818
# Epoch 27/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.9488
# Epoch 00027: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 83s 673ms/step - loss: 0.1477 - accuracy: 0.9488 - val_loss: 0.9569 - val_accuracy: 0.7874
# Epoch 28/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9421
# Epoch 00028: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 83s 665ms/step - loss: 0.1609 - accuracy: 0.9421 - val_loss: 1.0816 - val_accuracy: 0.7979
# Epoch 29/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9419
# Epoch 00029: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 82s 665ms/step - loss: 0.1698 - accuracy: 0.9419 - val_loss: 0.6682 - val_accuracy: 0.7007
# Epoch 30/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1640 - accuracy: 0.9426
# Epoch 00030: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 82s 662ms/step - loss: 0.1640 - accuracy: 0.9426 - val_loss: 0.9836 - val_accuracy: 0.7798
# Epoch 31/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9438
# Epoch 00031: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 89s 715ms/step - loss: 0.1542 - accuracy: 0.9438 - val_loss: 0.4337 - val_accuracy: 0.8160
# Epoch 32/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9464
# Epoch 00032: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 91s 735ms/step - loss: 0.1468 - accuracy: 0.9464 - val_loss: 0.3482 - val_accuracy: 0.8627
# Epoch 33/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.9476
# Epoch 00033: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 90s 727ms/step - loss: 0.1383 - accuracy: 0.9476 - val_loss: 0.3256 - val_accuracy: 0.9075
# Epoch 34/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1506 - accuracy: 0.9469
# Epoch 00034: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 91s 734ms/step - loss: 0.1506 - accuracy: 0.9469 - val_loss: 1.3209 - val_accuracy: 0.7550
# Epoch 35/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1437 - accuracy: 0.9471
# Epoch 00035: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 91s 731ms/step - loss: 0.1437 - accuracy: 0.9471 - val_loss: 0.5912 - val_accuracy: 0.8389
# Epoch 36/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9517
# Epoch 00036: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 91s 734ms/step - loss: 0.1349 - accuracy: 0.9517 - val_loss: 0.2957 - val_accuracy: 0.8990
# Epoch 37/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9469
# Epoch 00037: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 92s 738ms/step - loss: 0.1403 - accuracy: 0.9469 - val_loss: 0.4662 - val_accuracy: 0.8456
# Epoch 38/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1433 - accuracy: 0.9505
# Epoch 00038: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 91s 735ms/step - loss: 0.1433 - accuracy: 0.9505 - val_loss: 0.3161 - val_accuracy: 0.8932
# Epoch 39/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9457
# Epoch 00039: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 91s 731ms/step - loss: 0.1507 - accuracy: 0.9457 - val_loss: 1.4777 - val_accuracy: 0.6692
# Epoch 40/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9526
# Epoch 00040: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 94s 756ms/step - loss: 0.1324 - accuracy: 0.9526 - val_loss: 0.8801 - val_accuracy: 0.7531
# Epoch 41/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1338 - accuracy: 0.9493
# Epoch 00041: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 93s 753ms/step - loss: 0.1338 - accuracy: 0.9493 - val_loss: 0.2636 - val_accuracy: 0.8990
# Epoch 42/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9550
# Epoch 00042: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 92s 740ms/step - loss: 0.1226 - accuracy: 0.9550 - val_loss: 0.3966 - val_accuracy: 0.8856
# Epoch 43/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9521
# Epoch 00043: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 93s 753ms/step - loss: 0.1255 - accuracy: 0.9521 - val_loss: 0.3796 - val_accuracy: 0.8789
# Epoch 44/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9500
# Epoch 00044: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 93s 747ms/step - loss: 0.1375 - accuracy: 0.9500 - val_loss: 0.4494 - val_accuracy: 0.8608
# Epoch 45/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9567
# Epoch 00045: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 93s 749ms/step - loss: 0.1243 - accuracy: 0.9567 - val_loss: 0.4208 - val_accuracy: 0.8875
# Epoch 46/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9493
# Epoch 00046: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 93s 748ms/step - loss: 0.1382 - accuracy: 0.9493 - val_loss: 0.2935 - val_accuracy: 0.8885
# Epoch 47/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 0.9502
# Epoch 00047: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 92s 742ms/step - loss: 0.1292 - accuracy: 0.9502 - val_loss: 0.5339 - val_accuracy: 0.7598
# Epoch 48/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9507
# Epoch 00048: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 92s 742ms/step - loss: 0.1279 - accuracy: 0.9507 - val_loss: 0.3951 - val_accuracy: 0.8599
# Epoch 49/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9552
# Epoch 00049: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 92s 746ms/step - loss: 0.1295 - accuracy: 0.9552 - val_loss: 0.6530 - val_accuracy: 0.8332
# Epoch 50/50
# 124/124 [==============================] - ETA: 0s - loss: 0.1257 - accuracy: 0.9538
# Epoch 00050: val_accuracy did not improve from 0.91039
# 124/124 [==============================] - 94s 759ms/step - loss: 0.1257 - accuracy: 0.9538 - val_loss: 0.5915 - val_accuracy: 0.8475

# %%
y_img_batch, y_class_batch = test_batch[0] 
y_pred = np.argmax(my_net.predict(y_img_batch),-1)
y_true = np.argmax(y_class_batch,-1)

print(y_true.shape)
print(classification_report(y_true, y_pred))
# Out:
# (32,)
#               precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71        11
#            1       0.81      1.00      0.89        21
#
#     accuracy                           0.84        32
#    macro avg       0.90      0.77      0.80        32
# weighted avg       0.87      0.84      0.83        32

# %%
evalu = my_net.evaluate(test_batch)
print (evalu)
# Out:
# 21/21 [==============================] - 8s 364ms/step - loss: 0.7780 - accuracy: 0.8152
# [0.7780068516731262, 0.8152173757553101]
